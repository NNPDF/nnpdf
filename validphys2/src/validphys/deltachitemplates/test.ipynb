# %%
import matplotlib.pyplot as plt
from validphys import mplstyles
plt.style.use(str(mplstyles.smallstyle))
from validphys.api import API

# %%
figs = API.plot_pdfs(pdfs=['NNPDF31_nnlo_as_0118_1000_hessian_100','NNPDF31_nnlo_as_0118_1000'], 
                     normalize_to='NNPDF31_nnlo_as_0118_1000', Q=1.7)
for f, _ in figs:
    f.tight_layout()

# %%
# 'runcard'
template = {'theory':{'from_': 'fit'},
                'theoryid':{'from_': 'theory'},
                'use_cuts': 'fromfit',
                'experiments':{
                'from_': 'fit'},
                'fit': 'NNPDF31_nnlo_as_0118_1000',
                'use_t0': True,
                't0pdfset': '170206-003',
                }
# 'plot_delta_chi2_hessian' implemented in validphys/dataplots
figs = API.plot_delta_chi2_hessian(pdf='NNPDF31_nnlo_as_0118_1000_hessian_100_Q_1.7', **template)

figs.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# InputNotFoundError                        Traceback (most recent call last)
# <ipython-input-5-44530b74b885> in <module>
#      10                 }
#      11 # 'plot_delta_chi2_hessian' implemented in validphys/dataplots
# ---> 12 figs = API.plot_delta_chi2_hessian(pdf='NNPDF31_nnlo_as_0118_1000_hessian_100_Q_1.7', **template)
#      13
#      14 figs.tight_layout()
#
# ~/miniconda3/envs/mc2hessian/lib/python3.7/site-packages/reportengine/api.py in closure(**kwargs)
#      41     def __getattr__(self, name):
#      42         def closure(**kwargs):
# ---> 43             return self.__call__(name, **kwargs)
#      44         return closure
#
# ~/miniconda3/envs/mc2hessian/lib/python3.7/site-packages/reportengine/api.py in __call__(self, actions, **kwargs)
#      34         c = self.config_class(kwargs, environment=self.loadedenv)
# ...

# %%
figs = API.plot_epsilon(pdfs=['PN3_DISonly_planA_step5'], Q=1.7, ymin=0, ymax=2, eps=.6)

for f, _ in figs:
    f.tight_layout()

# %%
figs = API.plot_pdfs(pdfs=['NNPDF31_nnlo_as_0118_1000_hessian_100',
                           'NNPDF31_pos_delta_chi2',
                           'NNPDF31_neg_delta_chi2'], 
                     normalize_to='NNPDF31_nnlo_as_0118_1000_hessian_100', Q=1.7)

for f, _ in figs:
    f.tight_layout()
