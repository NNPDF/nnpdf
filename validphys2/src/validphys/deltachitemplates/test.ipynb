# %%
import matplotlib.pyplot as plt
from validphys import mplstyles
plt.style.use(str(mplstyles.smallstyle))
from validphys.api import API

# %%
figs = API.plot_pdfs(pdfs=['NNPDF31_nnlo_as_0118_1000_hessian_100','NNPDF31_nnlo_as_0118_1000'], 
                     normalize_to='NNPDF31_nnlo_as_0118_1000', Q=1.7)
for f, _ in figs:
    f.tight_layout()
# Out:
# Resource not in the remote repository: PDF 'NNPDF31_nnlo_as_0118_1000_hessian_100' is neither an uploaded fit nor an LHAPDF set.
# Failed processing key pdfs.
# ---------------------------------------------------------------------------
# PDFNotFound                               Traceback (most recent call last)
# ~/github/NNPDF/nnpdf/validphys2/src/validphys/loader.py in f(*args, **kwargs)
#     908                 try:
# --> 909                     download(*args, **kwargs)
#     910                 except RemoteLoaderError as e:
#
# ~/github/NNPDF/nnpdf/validphys2/src/validphys/loader.py in download_pdf(self, name)
#     850             raise PDFNotFound("PDF '%s' is neither an uploaded fit nor an "
# --> 851                               "LHAPDF set." % name)
#     852
#
# PDFNotFound: PDF 'NNPDF31_nnlo_as_0118_1000_hessian_100' is neither an uploaded fit nor an LHAPDF set.
#
# During handling of the above exception, another exception occurred:
#
# ...
